# %% [markdown]
# # WeatherPy
# ----
#
# #### Observations:
# - The City Latitude vs. Max Temperature (Celcius) diagram indicates a relationship between the latitude and max temperatures (measured in degrees celsius) of individual cities in the sample dataset. It would appear that the max temperatures seem to be the highest for cities closest to the equator. The linear regression models would suggest that this correlation is stronger in the northern hemisphere over the South.
#
# - There would appear to be minimal relationship between the humidity and cloudiness of cities relative to their respective latitudes. That being said, there is a slightly better correlation (although still weak) trend between these variables in the Southern Hermisphere than the North.
#
# - With respect to wind speed and latitudes, whilst there does not appear to be a particularly strong relationship between the two variables, the scatterplots would appear to suggest that that is greater variability of wind speeds further away from the equator.
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#dependencies et al.
import matplotlib.pyplot as plt
import json
import requests
import pandas as pd
import numpy as np
import time

#api_keys
import api_keys

#citipy
from citipy import citipy

#range of lats and longs - https://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm
lat_range = (-90, 90)
long_range = (-180, 180)

#output file
output_file = "../output_data/cities_final.csv"

# %% [markdown]
# ## Generate Cities List

# %%
#https://github.com/wingchen/citipy

#create list for storing lat, long conbination to be then fed into citipy.
lats_longs = []
cities = []

#https://numpy.org/doc/stable/reference/random/generated/numpy.random.uniform.html
latitudes = np.random.uniform(-90.000, 90.000, 2000)
longtitudes = np.random.uniform(-180.000, 180.000, 2000)
lats_longs = zip(latitudes, longtitudes)

#use citipy to find city matching lats_longs combination
for lat_long in lats_longs:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    #https://stackoverflow.com/questions/38872376/get-the-weather-for-cities-with-names-that-contain-spaces-using-openweathermap
    city = city.replace(" ",  "%20")
    #store into cities list only unique values from city
    if city not in cities:
        cities.append(city)

#number of result to determine if 500 city sample condition will be met
len(cities)
# print(cities)
# Out:
# 797

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# #Test to verify that query and keys work
# # OpenWeatherMap API Key

# api_key = api_keys.weather_api_key

# # Save config information.
# url = "http://api.openweathermap.org/data/2.5/weather?"
# units = "metric"

# query_url = f"{url}appid={api_key}&units={units}&q="
# response = requests.get(query_url + "perth").json()
# response

# %%
# OpenWeatherMap API Key
api_key = api_keys.weather_api_key

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={api_key}&units={units}&q="

#what are we retrieving? create lists for each of these
lng = []
lat = []
country = []
sunrise = []
sunset = []
date = []
temp_max = []
temp_min = []
temp_feels = []
humidity = []
cloudiness = []
wind_speed = []
city_name = []

record = 0
set_number = 1

#print statements
print(f"Beginning Data Retrieval\n-------------------------------")

#loop to cycle through cities list to obtain information for DF.
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        sunrise.append(response['sys']['sunrise'])
        sunset.append(response['sys']['sunset'])
        cloudiness.append(response['clouds']['all'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp_max.append(response['main']['temp_max'])
        temp_min.append(response['main']['temp_min'])
        temp_feels.append(response['main']['feels_like'])
        wind_speed.append(response['wind']['speed'])
        if record > 49:
            record = 1
            set_number += 1
            city_name.append(response['name'])
        else:
            record += 1
            city_name.append(response['name'])
            
        print(f"Processing Record {record} of Set {set_number} | {response['name']}")
                                
    except Exception:
        print("City not found. Skipping...")
        
    #free API limited to 60 calls / minute - https://www.programiz.com/python-programming/time/sleep
    time.sleep(1.01)
    
print(f"-------------------------------\
      \nData Retrieval Complete\
      \n-------------------------------\
      \nThe number of datapoints data sets retrieved is {len(city_name)}")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | Albany
# Processing Record 2 of Set 1 | George Town
# Processing Record 3 of Set 1 | Mataura
# Processing Record 4 of Set 1 | Biak
# Processing Record 5 of Set 1 | Poum
# Processing Record 6 of Set 1 | Tiksi
# Processing Record 7 of Set 1 | Kavieng
# Processing Record 8 of Set 1 | Hobart
# Processing Record 9 of Set 1 | Lander
# Processing Record 10 of Set 1 | Caxito
# Processing Record 11 of Set 1 | Tasiilaq
# Processing Record 12 of Set 1 | Rikitea
# Processing Record 13 of Set 1 | La Ronge
# Processing Record 14 of Set 1 | Bengkulu
# Processing Record 15 of Set 1 | Torbay
# Processing Record 16 of Set 1 | Busselton
# Processing Record 17 of Set 1 | Buenavista
# Processing Record 18 of Set 1 | Ushuaia
# Processing Record 19 of Set 1 | Flin Flon
# City not found. Skipping...
# Processing Record 20 of Set 1 | Khovd
# Processing Record 21 of Set 1 | Cabo San Lucas
# Processing Record 22 of Set 1 | Bluff
# City not found. Skipping...
# Processing Record 23 of Set 1 | Avera
# City not found. Skipping...
# Processing Record 24 of Set 1 | Saint-Prosper
# Processing Record 25 of Set 1 | Hermanus
# City not found. Skipping...
# Processing Record 26 of Set 1 | Tommot
# Processing Record 27 of Set 1 | Flinders
# Processing Record 28 of Set 1 | Upernavik
# Processing Record 29 of Set 1 | Airai
# Processing Record 30 of Set 1 | Kapaa
# Processing Record 31 of Set 1 | Haines Junction
# Processing Record 32 of Set 1 | Bhāyāvadar
# Processing Record 33 of Set 1 | Chui
# City not found. Skipping...
# Processing Record 34 of Set 1 | Coyhaique
# Processing Record 35 of Set 1 | Ugoofaaru
# Processing Record 36 of Set 1 | Kavaratti
# Processing Record 37 of Set 1 | Punta Arenas
# Processing Record 38 of Set 1 | Chapleau
# Processing Record 39 of Set 1 | Lompoc
# Processing Record 40 of Set 1 | Ahipara
# Processing Record 41 of Set 1 | Nikolskoye
# Processing Record 42 of Set 1 | Ojinaga
# Processing Record 43 of Set 1 | Lebu
# Processing Record 44 of Set 1 | Hong Kong
# Processing Record 45 of Set 1 | Sitka
# Processing Record 46 of Set 1 | Vaini
# Processing Record 47 of Set 1 | Souillac
# Processing Record 48 of Set 1 | La Santisima Trinidad
# Processing Record 49 of Set 1 | Spencer
# City not found. Skipping...
# Processing Record 50 of Set 1 | Cape Town
# Processing Record 1 of Set 2 | Rio Grande
# Processing Record 2 of Set 2 | Guerrero Negro
# Processing Record 3 of Set 2 | Comodoro Rivadavia
# Processing Record 4 of Set 2 | Kirakira
# Processing Record 5 of Set 2 | Resistencia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 2 | Jamestown
# Processing Record 7 of Set 2 | Dikson
# Processing Record 8 of Set 2 | Mananjary
# City not found. Skipping...
# Processing Record 9 of Set 2 | Hirara
# Processing Record 10 of Set 2 | Longyearbyen
# Processing Record 11 of Set 2 | Yellowknife
# Processing Record 12 of Set 2 | Sorada
# Processing Record 13 of Set 2 | Clyde River
# Processing Record 14 of Set 2 | Nouakchott
# Processing Record 15 of Set 2 | Cañete
# Processing Record 16 of Set 2 | Khatanga
# Processing Record 17 of Set 2 | Zahesi
# Processing Record 18 of Set 2 | Aripuanã
# Processing Record 19 of Set 2 | Kathmandu
# Processing Record 20 of Set 2 | Buala
# Processing Record 21 of Set 2 | Puerto Ayora
# Processing Record 22 of Set 2 | Laguna
# Processing Record 23 of Set 2 | Gamboula
# Processing Record 24 of Set 2 | Adrar
# Processing Record 25 of Set 2 | Praxédis Guerrero
# Processing Record 26 of Set 2 | Sosnovo-Ozerskoye
# City not found. Skipping...
# Processing Record 27 of Set 2 | Mar del Plata
# Processing Record 28 of Set 2 | Bafia
# Processing Record 29 of Set 2 | San Patricio
# Processing Record 30 of Set 2 | Saldanha
# Processing Record 31 of Set 2 | Usinsk
# Processing Record 32 of Set 2 | Sarangani
# Processing Record 33 of Set 2 | Wairoa
# Processing Record 34 of Set 2 | Nyurba
# Processing Record 35 of Set 2 | Hervey Bay
# Processing Record 36 of Set 2 | Deputatsky
# Processing Record 37 of Set 2 | Angoche
# Processing Record 38 of Set 2 | Bundaberg
# Processing Record 39 of Set 2 | Savannah Bight
# Processing Record 40 of Set 2 | Hilo
# Processing Record 41 of Set 2 | Marand
# Processing Record 42 of Set 2 | Ostrovnoy
# Processing Record 43 of Set 2 | Esperance
# Processing Record 44 of Set 2 | Maracaju
# Processing Record 45 of Set 2 | Vila
# Processing Record 46 of Set 2 | Chokurdakh
# Processing Record 47 of Set 2 | Ghanzi
# Processing Record 48 of Set 2 | Ciudad del Carmen
# Processing Record 49 of Set 2 | Port Alfred
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 2 | Kaitangata
# Processing Record 1 of Set 3 | Yinchuan
# Processing Record 2 of Set 3 | Bambous Virieux
# Processing Record 3 of Set 3 | Madison
# Processing Record 4 of Set 3 | Port Elizabeth
# Processing Record 5 of Set 3 | East London
# Processing Record 6 of Set 3 | Touros
# Processing Record 7 of Set 3 | Hithadhoo
# Processing Record 8 of Set 3 | Maniitsoq
# Processing Record 9 of Set 3 | Neryungri
# Processing Record 10 of Set 3 | Isangel
# Processing Record 11 of Set 3 | Midland
# Processing Record 12 of Set 3 | Vila Velha
# Processing Record 13 of Set 3 | Yar-Sale
# Processing Record 14 of Set 3 | Tura
# City not found. Skipping...
# Processing Record 15 of Set 3 | Nchelenge
# Processing Record 16 of Set 3 | Skowhegan
# Processing Record 17 of Set 3 | La Palma
# Processing Record 18 of Set 3 | New Norfolk
# Processing Record 19 of Set 3 | Gold Coast
# Processing Record 20 of Set 3 | Dingle
# Processing Record 21 of Set 3 | Havøysund
# Processing Record 22 of Set 3 | Bānda
# Processing Record 23 of Set 3 | Leningradskiy
# Processing Record 24 of Set 3 | Eyemouth
# Processing Record 25 of Set 3 | Baruun-Urt
# Processing Record 26 of Set 3 | Ancud
# Processing Record 27 of Set 3 | Bireun
# Processing Record 28 of Set 3 | Kayerkan
# Processing Record 29 of Set 3 | Maceió
# Processing Record 30 of Set 3 | Kahului
# City not found. Skipping...
# Processing Record 31 of Set 3 | Mahébourg
# Processing Record 32 of Set 3 | Kruisfontein
# Processing Record 33 of Set 3 | Barrow
# Processing Record 34 of Set 3 | Grindavik
# Processing Record 35 of Set 3 | Rawson
# Processing Record 36 of Set 3 | Ngunguru
# Processing Record 37 of Set 3 | Hunchun
# Processing Record 38 of Set 3 | Dholka
# Processing Record 39 of Set 3 | Cidreira
# Processing Record 40 of Set 3 | Port Moresby
# Processing Record 41 of Set 3 | Port Augusta
# Processing Record 42 of Set 3 | Kloulklubed
# Processing Record 43 of Set 3 | Namatanai
# City not found. Skipping...
# Processing Record 44 of Set 3 | Arraial do Cabo
# Processing Record 45 of Set 3 | Mocuba
# Processing Record 46 of Set 3 | Saint-Philippe
# Processing Record 47 of Set 3 | Tucumã
# Processing Record 48 of Set 3 | Portland
# Processing Record 49 of Set 3 | Avarua
# Processing Record 50 of Set 3 | Zhigansk
# Processing Record 1 of Set 4 | Iqaluit
# Processing Record 2 of Set 4 | Whitehorse
# Processing Record 3 of Set 4 | Hambantota
# Processing Record 4 of Set 4 | Faanui
# Processing Record 5 of Set 4 | Blagoyevo
# Processing Record 6 of Set 4 | Santa Cruz
# Processing Record 7 of Set 4 | Poso
# Processing Record 8 of Set 4 | Shelburne
# Processing Record 9 of Set 4 | Cockburn Town
# City not found. Skipping...
# Processing Record 10 of Set 4 | Bakchar
# Processing Record 11 of Set 4 | Tuatapere
# Processing Record 12 of Set 4 | Wattegama
# Processing Record 13 of Set 4 | Puerto Colombia
# Processing Record 14 of Set 4 | Vostok
# Processing Record 15 of Set 4 | Klaksvík
# Processing Record 16 of Set 4 | Meulaboh
# Processing Record 17 of Set 4 | Thompson
# Processing Record 18 of Set 4 | Tulsīpur
# Processing Record 19 of Set 4 | Sept-Îles
# Processing Record 20 of Set 4 | Quatre Cocos
# Processing Record 21 of Set 4 | Santa Maria
# Processing Record 22 of Set 4 | Butaritari
# Processing Record 23 of Set 4 | Kapit
# Processing Record 24 of Set 4 | Naze
# Processing Record 25 of Set 4 | Grand-Lahou
# Processing Record 26 of Set 4 | Ribeira Grande
# Processing Record 27 of Set 4 | Burley
# Processing Record 28 of Set 4 | Kushmurun
# Processing Record 29 of Set 4 | Grabouw
# Processing Record 30 of Set 4 | Kidal
# Processing Record 31 of Set 4 | Tiznit Province
# Processing Record 32 of Set 4 | São Filipe
# Processing Record 33 of Set 4 | Abu Kamal
# Processing Record 34 of Set 4 | Nhulunbuy
# Processing Record 35 of Set 4 | Port Hedland
# City not found. Skipping...
# Processing Record 36 of Set 4 | Faya
# Processing Record 37 of Set 4 | Santa Cruz de la Sierra
# Processing Record 38 of Set 4 | Caldas Novas
# Processing Record 39 of Set 4 | Saint Paul Harbor
# Processing Record 40 of Set 4 | Wanxian
# Processing Record 41 of Set 4 | Glens Falls
# Processing Record 42 of Set 4 | Pak Phanang
# Processing Record 43 of Set 4 | Lata
# Processing Record 44 of Set 4 | Half Moon Bay
# Processing Record 45 of Set 4 | Davila
# City not found. Skipping...
# Processing Record 46 of Set 4 | Eilat
# Processing Record 47 of Set 4 | Along
# Processing Record 48 of Set 4 | Belyy Yar
# Processing Record 49 of Set 4 | Vardø
# Processing Record 50 of Set 4 | Samarai
# City not found. Skipping...
# Processing Record 1 of Set 5 | Bowen
# Processing Record 2 of Set 5 | Bredasdorp
# Processing Record 3 of Set 5 | Shimoda
# Processing Record 4 of Set 5 | Poplar Bluff
# Processing Record 5 of Set 5 | Macaúbas
# Processing Record 6 of Set 5 | Humpolec
# Processing Record 7 of Set 5 | Marabu
# Processing Record 8 of Set 5 | Sokolo
# Processing Record 9 of Set 5 | Beira
# City not found. Skipping...
# Processing Record 10 of Set 5 | Dunedin
# Processing Record 11 of Set 5 | Penne
# Processing Record 12 of Set 5 | Udomlya
# Processing Record 13 of Set 5 | Port Hardy
# Processing Record 14 of Set 5 | Zhezkazgan
# Processing Record 15 of Set 5 | Taltal
# Processing Record 16 of Set 5 | Laas
# Processing Record 17 of Set 5 | Merauke
# Processing Record 18 of Set 5 | Yabēlo
# Processing Record 19 of Set 5 | Yulara
# City not found. Skipping...
# Processing Record 20 of Set 5 | Monastyrshchina
# Processing Record 21 of Set 5 | Coquimbo
# Processing Record 22 of Set 5 | Pouembout
# Processing Record 23 of Set 5 | Talnakh
# Processing Record 24 of Set 5 | Lüderitz
# Processing Record 25 of Set 5 | Bantogon
# Processing Record 26 of Set 5 | Ixtapa
# Processing Record 27 of Set 5 | Seoul
# City not found. Skipping...
# Processing Record 28 of Set 5 | Srednekolymsk
# Processing Record 29 of Set 5 | Kargasok
# Processing Record 30 of Set 5 | Bubaque
# City not found. Skipping...
# Processing Record 31 of Set 5 | Kholodnyy
# City not found. Skipping...
# Processing Record 32 of Set 5 | Akdepe
# Processing Record 33 of Set 5 | Mogadishu
# Processing Record 34 of Set 5 | Olafsvik
# Processing Record 35 of Set 5 | Fairbanks
# Processing Record 36 of Set 5 | Pundaguitan
# Processing Record 37 of Set 5 | Pacific Grove
# Processing Record 38 of Set 5 | Weyburn
# Processing Record 39 of Set 5 | Glace Bay
# Processing Record 40 of Set 5 | Mount Isa
# Processing Record 41 of Set 5 | Kununurra
# Processing Record 42 of Set 5 | Kedrovyy
# Processing Record 43 of Set 5 | Kyra
# Processing Record 44 of Set 5 | Divnogorsk
# Processing Record 45 of Set 5 | Ilulissat
# Processing Record 46 of Set 5 | Castro
# Processing Record 47 of Set 5 | Carnarvon
# Processing Record 48 of Set 5 | Plomari
# Processing Record 49 of Set 5 | Northam
# Processing Record 50 of Set 5 | Berlevåg
# Processing Record 1 of Set 6 | Qaanaaq
# Processing Record 2 of Set 6 | Muros
# Processing Record 3 of Set 6 | The Valley
# Processing Record 4 of Set 6 | Cururupu
# Processing Record 5 of Set 6 | Coaraci
# Processing Record 6 of Set 6 | Merke
# Processing Record 7 of Set 6 | Nemuro
# Processing Record 8 of Set 6 | Pochutla
# Processing Record 9 of Set 6 | Te Anau
# Processing Record 10 of Set 6 | Mahon
# Processing Record 11 of Set 6 | Morón
# Processing Record 12 of Set 6 | Kyabé
# Processing Record 13 of Set 6 | Boquete
# Processing Record 14 of Set 6 | Castelnau-le-Lez
# City not found. Skipping...
# Processing Record 15 of Set 6 | Porto Walter
# Processing Record 16 of Set 6 | Presidencia Roque Sáenz Peña
# Processing Record 17 of Set 6 | Bethalto
# Processing Record 18 of Set 6 | Pevek
# Processing Record 19 of Set 6 | Baghdad
# Processing Record 20 of Set 6 | Bayonet Point
# Processing Record 21 of Set 6 | Trelew
# Processing Record 22 of Set 6 | Khanbari
# Processing Record 23 of Set 6 | Raudeberg
# Processing Record 24 of Set 6 | Itoman
# Processing Record 25 of Set 6 | Les Cayes
# Processing Record 26 of Set 6 | Hendek
# Processing Record 27 of Set 6 | Olpād
# Processing Record 28 of Set 6 | Alekseyevsk
# Processing Record 29 of Set 6 | Acapulco de Juárez
# Processing Record 30 of Set 6 | Aktau
# Processing Record 31 of Set 6 | Belmonte
# Processing Record 32 of Set 6 | Saskylakh
# Processing Record 33 of Set 6 | Beloha
# Processing Record 34 of Set 6 | Necaxa
# Processing Record 35 of Set 6 | Rome
# Processing Record 36 of Set 6 | Constitución
# Processing Record 37 of Set 6 | Tuktoyaktuk
# Processing Record 38 of Set 6 | Atuona
# Processing Record 39 of Set 6 | Orleans
# Processing Record 40 of Set 6 | Chambersburg
# Processing Record 41 of Set 6 | Bandarbeyla
# Processing Record 42 of Set 6 | Almaznyy
# Processing Record 43 of Set 6 | Severo-Kuril'sk
# Processing Record 44 of Set 6 | Lakes Entrance
# Processing Record 45 of Set 6 | Krasnosel'kup
# Processing Record 46 of Set 6 | São João da Barra
# Processing Record 47 of Set 6 | San Fernando
# Processing Record 48 of Set 6 | Austin
# Processing Record 49 of Set 6 | Cleethorpes
# Processing Record 50 of Set 6 | Barcelona
# Processing Record 1 of Set 7 | Vanimo
# Processing Record 2 of Set 7 | Plettenberg Bay
# Processing Record 3 of Set 7 | Santiago del Estero
# Processing Record 4 of Set 7 | Verkhoyansk
# Processing Record 5 of Set 7 | Calabozo
# Processing Record 6 of Set 7 | Pacifica
# Processing Record 7 of Set 7 | Ust-Kuyga
# Processing Record 8 of Set 7 | Padang
# City not found. Skipping...
# Processing Record 9 of Set 7 | Kargat
# Processing Record 10 of Set 7 | Yumen
# City not found. Skipping...
# Processing Record 11 of Set 7 | Bom Conselho
# Processing Record 12 of Set 7 | Caravelas
# Processing Record 13 of Set 7 | Sibolga
# Processing Record 14 of Set 7 | Atar
# Processing Record 15 of Set 7 | Hualmay
# Processing Record 16 of Set 7 | Beidao
# Processing Record 17 of Set 7 | Mirabela
# Processing Record 18 of Set 7 | Salalah
# Processing Record 19 of Set 7 | Derzhavīnsk
# Processing Record 20 of Set 7 | Gävle
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 7 | Ketchikan
# Processing Record 22 of Set 7 | Akureyri
# Processing Record 23 of Set 7 | Severo-Yeniseyskiy
# Processing Record 24 of Set 7 | Henties Bay
# Processing Record 25 of Set 7 | Erenhot
# Processing Record 26 of Set 7 | Saint George
# Processing Record 27 of Set 7 | Lorengau
# Processing Record 28 of Set 7 | Ponta do Sol
# Processing Record 29 of Set 7 | Nandigāma
# Processing Record 30 of Set 7 | Khilchipur
# Processing Record 31 of Set 7 | Bara
# Processing Record 32 of Set 7 | Cayenne
# Processing Record 33 of Set 7 | Dicabisagan
# Processing Record 34 of Set 7 | Fortuna
# Processing Record 35 of Set 7 | Mbaïki
# City not found. Skipping...
# Processing Record 36 of Set 7 | Huilong
# Processing Record 37 of Set 7 | Christchurch
# City not found. Skipping...
# Processing Record 38 of Set 7 | Fort-Shevchenko
# Processing Record 39 of Set 7 | Ulverstone
# Processing Record 40 of Set 7 | Soe
# Processing Record 41 of Set 7 | Ballina
# Processing Record 42 of Set 7 | Nuuk
# Processing Record 43 of Set 7 | Codrington
# Processing Record 44 of Set 7 | Makakilo City
# Processing Record 45 of Set 7 | Nome
# Processing Record 46 of Set 7 | Morant Bay
# Processing Record 47 of Set 7 | Boa Vista
# Processing Record 48 of Set 7 | Spasskoye
# Processing Record 49 of Set 7 | Alta Floresta
# Processing Record 50 of Set 7 | Rāzole
# Processing Record 1 of Set 8 | Hailun
# Processing Record 2 of Set 8 | Inuvik
# Processing Record 3 of Set 8 | Nelson Bay
# City not found. Skipping...
# Processing Record 4 of Set 8 | Kwekwe
# Processing Record 5 of Set 8 | Bathsheba
# City not found. Skipping...
# Processing Record 6 of Set 8 | Pisco
# Processing Record 7 of Set 8 | Saint-Ambroise
# Processing Record 8 of Set 8 | Lagoa
# Processing Record 9 of Set 8 | Popondetta
# Processing Record 10 of Set 8 | Cienfuegos
# Processing Record 11 of Set 8 | Gumdag
# Processing Record 12 of Set 8 | Bonavista
# Processing Record 13 of Set 8 | Grootfontein
# Processing Record 14 of Set 8 | Linxia Chengguanzhen
# Processing Record 15 of Set 8 | Okha
# Processing Record 16 of Set 8 | Bastos
# Processing Record 17 of Set 8 | Mumford
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 8 | Batemans Bay
# Processing Record 19 of Set 8 | Saint John
# Processing Record 20 of Set 8 | Junín
# Processing Record 21 of Set 8 | Healdsburg
# Processing Record 22 of Set 8 | Banda Aceh
# Processing Record 23 of Set 8 | Dubbo
# Processing Record 24 of Set 8 | Kozhva
# Processing Record 25 of Set 8 | Dudinka
# Processing Record 26 of Set 8 | Amboasary
# Processing Record 27 of Set 8 | Tsimmerbude
# Processing Record 28 of Set 8 | Gewanē
# Processing Record 29 of Set 8 | Bahía de Caráquez
# Processing Record 30 of Set 8 | Grand Gaube
# Processing Record 31 of Set 8 | Cherskiy
# Processing Record 32 of Set 8 | Sande
# City not found. Skipping...
# Processing Record 33 of Set 8 | Katobu
# Processing Record 34 of Set 8 | Taoudenni
# Processing Record 35 of Set 8 | Saint-Augustin
# Processing Record 36 of Set 8 | Russell
# Processing Record 37 of Set 8 | Kangaatsiaq
# Processing Record 38 of Set 8 | Massakory
# Processing Record 39 of Set 8 | Florida
# Processing Record 40 of Set 8 | Margate
# Processing Record 41 of Set 8 | Griffith
# Processing Record 42 of Set 8 | Bairiki Village
# Processing Record 43 of Set 8 | Manavālakurichi
# Processing Record 44 of Set 8 | Norman Wells
# Processing Record 45 of Set 8 | Tarauacá
# Processing Record 46 of Set 8 | Suntar
# Processing Record 47 of Set 8 | Naranjal
# Processing Record 48 of Set 8 | Thoen
# Processing Record 49 of Set 8 | Port Blair
# Processing Record 50 of Set 8 | Fort Nelson
# Processing Record 1 of Set 9 | Lalibela
# Processing Record 2 of Set 9 | Pandan
# Processing Record 3 of Set 9 | Abū Zabad
# Processing Record 4 of Set 9 | Petropavlovsk-Kamchatskiy
# Processing Record 5 of Set 9 | Alice Springs
# Processing Record 6 of Set 9 | Ayagoz
# Processing Record 7 of Set 9 | Kalmunai
# Processing Record 8 of Set 9 | Tarakan
# Processing Record 9 of Set 9 | Øksfjord
# Processing Record 10 of Set 9 | Yangjiang
# Processing Record 11 of Set 9 | Nikol'sk
# Processing Record 12 of Set 9 | Hay River
# Processing Record 13 of Set 9 | Azul
# Processing Record 14 of Set 9 | Payo
# Processing Record 15 of Set 9 | Ughelli
# Processing Record 16 of Set 9 | Ikom
# City not found. Skipping...
# Processing Record 17 of Set 9 | Conceição da Barra
# Processing Record 18 of Set 9 | Mossamedes
# Processing Record 19 of Set 9 | Puerto Escondido
# Processing Record 20 of Set 9 | Port-Gentil
# Processing Record 21 of Set 9 | Micheweni
# Processing Record 22 of Set 9 | Craig
# Processing Record 23 of Set 9 | Bilma
# Processing Record 24 of Set 9 | Progreso
# Processing Record 25 of Set 9 | La Antigua
# Processing Record 26 of Set 9 | Vila Franca do Campo
# Processing Record 27 of Set 9 | Porto-Novo
# Processing Record 28 of Set 9 | Phayakkhaphum Phisai
# Processing Record 29 of Set 9 | Homer
# Processing Record 30 of Set 9 | Mountain Home
# Processing Record 31 of Set 9 | Ambilobe
# Processing Record 32 of Set 9 | Bethel
# Processing Record 33 of Set 9 | Labuhan
# Processing Record 34 of Set 9 | Lavrentiya
# Processing Record 35 of Set 9 | Beaverlodge
# City not found. Skipping...
# Processing Record 36 of Set 9 | Antofagasta
# Processing Record 37 of Set 9 | Zaysan
# Processing Record 38 of Set 9 | Freeport
# Processing Record 39 of Set 9 | Nago
# City not found. Skipping...
# Processing Record 40 of Set 9 | Ustyuzhna
# Processing Record 41 of Set 9 | Menomonie
# Processing Record 42 of Set 9 | Marawi
# Processing Record 43 of Set 9 | Ābdānān
# Processing Record 44 of Set 9 | Kon Tum
# Processing Record 45 of Set 9 | Pokhara
# Processing Record 46 of Set 9 | Drayton Valley
# Processing Record 47 of Set 9 | Staicele
# Processing Record 48 of Set 9 | Opuwo
# Processing Record 49 of Set 9 | Abu Dhabi
# City not found. Skipping...
# Processing Record 50 of Set 9 | Hebi
# Processing Record 1 of Set 10 | Margahayu
# Processing Record 2 of Set 10 | Dunda
# Processing Record 3 of Set 10 | Manggar
# Processing Record 4 of Set 10 | Santa Cruz del Sur
# Processing Record 5 of Set 10 | Itarema
# Processing Record 6 of Set 10 | Boysun
# Processing Record 7 of Set 10 | Honningsvåg
# City not found. Skipping...
# Processing Record 8 of Set 10 | Karratha
# Processing Record 9 of Set 10 | Astoria
# Processing Record 10 of Set 10 | Rocha
# Processing Record 11 of Set 10 | Kisarazu
# Processing Record 12 of Set 10 | Gigmoto
# Processing Record 13 of Set 10 | Görele
# Processing Record 14 of Set 10 | Luebo
# Processing Record 15 of Set 10 | Terney
# Processing Record 16 of Set 10 | Mandalgovi
# Processing Record 17 of Set 10 | Alofi
# Processing Record 18 of Set 10 | Kutum
# Processing Record 19 of Set 10 | Bela
# Processing Record 20 of Set 10 | Ola
# Processing Record 21 of Set 10 | Ubinskoye
# Processing Record 22 of Set 10 | Meadow Lake
# Processing Record 23 of Set 10 | Marabá
# Processing Record 24 of Set 10 | Ossora
# Processing Record 25 of Set 10 | Wahpeton
# Processing Record 26 of Set 10 | Baykit
# Processing Record 27 of Set 10 | Kharar
# Processing Record 28 of Set 10 | Nantucket
# Processing Record 29 of Set 10 | Hvolsvollur
# Processing Record 30 of Set 10 | Bilibino
# Processing Record 31 of Set 10 | Tyumen
# Processing Record 32 of Set 10 | Keti Bandar
# Processing Record 33 of Set 10 | Asău
# City not found. Skipping...
# Processing Record 34 of Set 10 | Wuda
# Processing Record 35 of Set 10 | Yoichi
# Processing Record 36 of Set 10 | Toowoomba
# Processing Record 37 of Set 10 | Balabac
# Processing Record 38 of Set 10 | Le Moule
# Processing Record 39 of Set 10 | Province of Mantua
# Processing Record 40 of Set 10 | Fraga
# Processing Record 41 of Set 10 | Kudahuvadhoo
# Processing Record 42 of Set 10 | Ucluelet
# Processing Record 43 of Set 10 | Aklavik
# Processing Record 44 of Set 10 | Timbiquí
# Processing Record 45 of Set 10 | Kwang Binh
# Processing Record 46 of Set 10 | Maningrida
# Processing Record 47 of Set 10 | Mackenzie
# Processing Record 48 of Set 10 | Indian Trail
# Processing Record 49 of Set 10 | Ust-Tsilma
# Processing Record 50 of Set 10 | Sistranda
# Processing Record 1 of Set 11 | Petatlán
# Processing Record 2 of Set 11 | Ankazoabo
# Processing Record 3 of Set 11 | Petrovsk
# Processing Record 4 of Set 11 | Mamlyutka
# Processing Record 5 of Set 11 | Neosho
# Processing Record 6 of Set 11 | Zaozyornoye
# Processing Record 7 of Set 11 | Yārāda
# Processing Record 8 of Set 11 | Lensk
# Processing Record 9 of Set 11 | Kamaishi
# Processing Record 10 of Set 11 | Vestmannaeyjar
# Processing Record 11 of Set 11 | The Pas
# Processing Record 12 of Set 11 | Aden
# Processing Record 13 of Set 11 | Gazli
# Processing Record 14 of Set 11 | Roald
# Processing Record 15 of Set 11 | Barichara
# Processing Record 16 of Set 11 | Chipinge
# Processing Record 17 of Set 11 | Porto Belo
# Processing Record 18 of Set 11 | Cortez
# Processing Record 19 of Set 11 | Guarapari
# Processing Record 20 of Set 11 | Port Lincoln
# Processing Record 21 of Set 11 | Araouane
# Processing Record 22 of Set 11 | Vangaindrano
# Processing Record 23 of Set 11 | Oistins
# Processing Record 24 of Set 11 | Çerkezköy
# Processing Record 25 of Set 11 | Xinxiang
# Processing Record 26 of Set 11 | Andenes
# Processing Record 27 of Set 11 | Ambon City
# Processing Record 28 of Set 11 | Kamenka
# Processing Record 29 of Set 11 | Najrān
# Processing Record 30 of Set 11 | Bay Roberts
# Processing Record 31 of Set 11 | Richards Bay
# Processing Record 32 of Set 11 | Khani
# Processing Record 33 of Set 11 | Semey
# Processing Record 34 of Set 11 | Prainha
# Processing Record 35 of Set 11 | Geraldton
# Processing Record 36 of Set 11 | Lima
# Processing Record 37 of Set 11 | Getulio Vargas
# Processing Record 38 of Set 11 | Leshukonskoye
# Processing Record 39 of Set 11 | Bloomingdale
# Processing Record 40 of Set 11 | Kieta
# Processing Record 41 of Set 11 | Nadym
# Processing Record 42 of Set 11 | Juba
# Processing Record 43 of Set 11 | Igpit
# Processing Record 44 of Set 11 | Tarpon Springs
# Processing Record 45 of Set 11 | Marsh Harbour
# Processing Record 46 of Set 11 | Praia
# Processing Record 47 of Set 11 | Narsaq
# Processing Record 48 of Set 11 | St. George's
# Processing Record 49 of Set 11 | Ayr
# Processing Record 50 of Set 11 | Hasaki
# Processing Record 1 of Set 12 | Mirny
# Processing Record 2 of Set 12 | Arari
# Processing Record 3 of Set 12 | San Cristobal
# Processing Record 4 of Set 12 | Kumul
# Processing Record 5 of Set 12 | Marshall
# City not found. Skipping...
# Processing Record 6 of Set 12 | Talaya
# Processing Record 7 of Set 12 | Sebezh
# Processing Record 8 of Set 12 | Arrondissement de Bastia
# Processing Record 9 of Set 12 | Broome
# Processing Record 10 of Set 12 | Kulykiv
# Processing Record 11 of Set 12 | Tezu
# Processing Record 12 of Set 12 | Marsabit
# Processing Record 13 of Set 12 | Inyonga
# Processing Record 14 of Set 12 | Puerto Quijarro
# Processing Record 15 of Set 12 | Shima
# Processing Record 16 of Set 12 | Los Llanos de Aridane
# Processing Record 17 of Set 12 | Kailua
# City not found. Skipping...
# Processing Record 18 of Set 12 | San Carlos del Zulia
# Processing Record 19 of Set 12 | Katsuura
# Processing Record 20 of Set 12 | Taganak
# City not found. Skipping...
# Processing Record 21 of Set 12 | Terdāl
# Processing Record 22 of Set 12 | Trincomalee
# Processing Record 23 of Set 12 | Epe
# Processing Record 24 of Set 12 | San Lorenzo
# Processing Record 25 of Set 12 | Poya
# Processing Record 26 of Set 12 | Karachi
# Processing Record 27 of Set 12 | Eydhafushi
# Processing Record 28 of Set 12 | Toma
# Processing Record 29 of Set 12 | Kiryat Gat
# Processing Record 30 of Set 12 | Teshie
# Processing Record 31 of Set 12 | Barra do Garças
# Processing Record 32 of Set 12 | Alugan
# Processing Record 33 of Set 12 | Palmer
# Processing Record 34 of Set 12 | Zemio
# Processing Record 35 of Set 12 | Treinta y Tres
# Processing Record 36 of Set 12 | Sukhinichi
# Processing Record 37 of Set 12 | Belaya Gora
# Processing Record 38 of Set 12 | Posse
# Processing Record 39 of Set 12 | Auki
# City not found. Skipping...
# Processing Record 40 of Set 12 | Laurel
# Processing Record 41 of Set 12 | Mount Darwin
# Processing Record 42 of Set 12 | Talcahuano
# Processing Record 43 of Set 12 | Dukat
# Processing Record 44 of Set 12 | Ende
# Processing Record 45 of Set 12 | North Little Rock
# Processing Record 46 of Set 12 | Pangnirtung
# Processing Record 47 of Set 12 | Kinshasa
# Processing Record 48 of Set 12 | Cuamba
# Processing Record 49 of Set 12 | Tazovsky
# Processing Record 50 of Set 12 | Anchorage
# Processing Record 1 of Set 13 | Sabang
# Processing Record 2 of Set 13 | Carauari
# Processing Record 3 of Set 13 | Yantal'
# Processing Record 4 of Set 13 | Burē
# Processing Record 5 of Set 13 | Walvis Bay
# Processing Record 6 of Set 13 | Springfield
# City not found. Skipping...
# Processing Record 7 of Set 13 | Kilindoni
# Processing Record 8 of Set 13 | Minot
# Processing Record 9 of Set 13 | Kyzyl-Suu
# Processing Record 10 of Set 13 | Coahuayana Viejo
# Processing Record 11 of Set 13 | Staryy Nadym
# Processing Record 12 of Set 13 | Motala
# Processing Record 13 of Set 13 | Singaparna
# Processing Record 14 of Set 13 | Zheleznogorsk
# Processing Record 15 of Set 13 | Porto Santo
# Processing Record 16 of Set 13 | Coihueco
# Processing Record 17 of Set 13 | Pāsighāt
# Processing Record 18 of Set 13 | Kapoeta
# Processing Record 19 of Set 13 | Megion
# Processing Record 20 of Set 13 | Changtu
# Processing Record 21 of Set 13 | Husavik
# Processing Record 22 of Set 13 | Kitimat
# City not found. Skipping...
# Processing Record 23 of Set 13 | George Town
# Processing Record 24 of Set 13 | Hofn
# Processing Record 25 of Set 13 | Bullhead City
# Processing Record 26 of Set 13 | Buraidah
# Processing Record 27 of Set 13 | Sheksna
# Processing Record 28 of Set 13 | Korla
# Processing Record 29 of Set 13 | Lázaro Cárdenas
# Processing Record 30 of Set 13 | Caudry
# Processing Record 31 of Set 13 | Nurota
# Processing Record 32 of Set 13 | Rosarito
# Processing Record 33 of Set 13 | Wanaka
# Processing Record 34 of Set 13 | Praia da Vitória
# Processing Record 35 of Set 13 | Mpongwe
# Processing Record 36 of Set 13 | Onalaska
# Processing Record 37 of Set 13 | Evensk
# Processing Record 38 of Set 13 | Ternate
# Processing Record 39 of Set 13 | Jiwani
# Processing Record 40 of Set 13 | College
# Processing Record 41 of Set 13 | Yarega
# Processing Record 42 of Set 13 | Abonnema
# Processing Record 43 of Set 13 | Villa Carlos Paz
# City not found. Skipping...
# Processing Record 44 of Set 13 | Smithers
# Processing Record 45 of Set 13 | Bouca
# Processing Record 46 of Set 13 | Madarounfa
# Processing Record 47 of Set 13 | Mersing
# Processing Record 48 of Set 13 | Burnie
# Processing Record 49 of Set 13 | Qaqortoq
# Processing Record 50 of Set 13 | Zhob
# Processing Record 1 of Set 14 | Sarāhan
# Processing Record 2 of Set 14 | Hayden
# Processing Record 3 of Set 14 | Sunrise Manor
# Processing Record 4 of Set 14 | Awjilah
# Processing Record 5 of Set 14 | Douentza
# City not found. Skipping...
# Processing Record 6 of Set 14 | Shitanjing
# Processing Record 7 of Set 14 | Mazatlán
# Processing Record 8 of Set 14 | Óbidos
# Processing Record 9 of Set 14 | Guangyuan
# Processing Record 10 of Set 14 | Agirish
# Processing Record 11 of Set 14 | Dhankutā
# Processing Record 12 of Set 14 | Sorong
# Processing Record 13 of Set 14 | Carndonagh
# Processing Record 14 of Set 14 | Jurm
# Processing Record 15 of Set 14 | Salinópolis
# Processing Record 16 of Set 14 | Cadillac
# Processing Record 17 of Set 14 | De Aar
# Processing Record 18 of Set 14 | Natal
# Processing Record 19 of Set 14 | Toyooka
# Processing Record 20 of Set 14 | Tual
# Processing Record 21 of Set 14 | Kirensk
# Processing Record 22 of Set 14 | Dembī Dolo
# Processing Record 23 of Set 14 | Alenquer
# Processing Record 24 of Set 14 | Monroe
# Processing Record 25 of Set 14 | Kendari
# Processing Record 26 of Set 14 | Dali
# Processing Record 27 of Set 14 | Tegul'det
# Processing Record 28 of Set 14 | Zatoka
# Processing Record 29 of Set 14 | La Orilla
# City not found. Skipping...
# Processing Record 30 of Set 14 | Provideniya
# Processing Record 31 of Set 14 | Eureka
# Processing Record 32 of Set 14 | Changji
# Processing Record 33 of Set 14 | Dauphin
# Processing Record 34 of Set 14 | Laramie
# Processing Record 35 of Set 14 | Limenaria
# Processing Record 36 of Set 14 | Port Hueneme
# Processing Record 37 of Set 14 | Haverfordwest
# City not found. Skipping...
# Processing Record 38 of Set 14 | Omboué
# Processing Record 39 of Set 14 | Kommunisticheskiy
# Processing Record 40 of Set 14 | Straumen
# Processing Record 41 of Set 14 | Charters Towers
# Processing Record 42 of Set 14 | Talas
# Processing Record 43 of Set 14 | Kefamenanu
# Processing Record 44 of Set 14 | San Juan
# Processing Record 45 of Set 14 | Chifeng
# Processing Record 46 of Set 14 | Mangai
# Processing Record 47 of Set 14 | Bien Hoa
# Processing Record 48 of Set 14 | Sambava
# City not found. Skipping...
# Processing Record 49 of Set 14 | Savé
# Processing Record 50 of Set 14 | Kyren
# Processing Record 1 of Set 15 | Kashgar
# Processing Record 2 of Set 15 | Mehamn
# Processing Record 3 of Set 15 | Yarensk
# Processing Record 4 of Set 15 | Farah
# Processing Record 5 of Set 15 | Novobirilyussy
# Processing Record 6 of Set 15 | Vao
# City not found. Skipping...
# Processing Record 7 of Set 15 | Sosnovoborsk
# Processing Record 8 of Set 15 | Gambēla
# Processing Record 9 of Set 15 | Kropotkin
# Processing Record 10 of Set 15 | Assiut
# Processing Record 11 of Set 15 | Cartagena del Chairá
# Processing Record 12 of Set 15 | Malé
# Processing Record 13 of Set 15 | Walla Walla
# Processing Record 14 of Set 15 | Teya
# Processing Record 15 of Set 15 | Dārāb
# Processing Record 16 of Set 15 | Tautira
# Processing Record 17 of Set 15 | Savelugu
# Processing Record 18 of Set 15 | Bonthe
# Processing Record 19 of Set 15 | North Platte
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 15 | Beyneu
# Processing Record 21 of Set 15 | Tianpeng
# Processing Record 22 of Set 15 | Platteville
# Processing Record 23 of Set 15 | Salinas
# Processing Record 24 of Set 15 | Atambua
# Processing Record 25 of Set 15 | Barra de Tecoanapa
# Processing Record 26 of Set 15 | Tangping
# Processing Record 27 of Set 15 | Fereydūnkenār
# Processing Record 28 of Set 15 | Oranjemund
# Processing Record 29 of Set 15 | Celestún
# Processing Record 30 of Set 15 | Beroroha
# City not found. Skipping...
# Processing Record 31 of Set 15 | Khabarovsk
# Processing Record 32 of Set 15 | Chicama
# Processing Record 33 of Set 15 | Yenagoa
# Processing Record 34 of Set 15 | Humberto de Campos
# Processing Record 35 of Set 15 | Mineiros
# Processing Record 36 of Set 15 | Ovalle
# Processing Record 37 of Set 15 | Skjervøy
# Processing Record 38 of Set 15 | Tieli
# Processing Record 39 of Set 15 | Chimoré
# Processing Record 40 of Set 15 | Prince Rupert
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# The number of datapoints data sets retrieved is 740

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#  from example csv. City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,Max Temp,Wind Speed
weather_dictionary = {
    "City":city_name,
    "Country":country,
    "Lat":lat,
    "Lng":lng,
    "Max Temp (Celsius)":temp_max,
    "Humidity %":humidity,
    "Cloudiness %":cloudiness,
    "Wind Speed (kmph)":wind_speed,
    "Date":date
}

# %%
city_weather = pd.DataFrame(weather_dictionary)
print(f' There are {city_weather["City"].count()} results in this dataframe')
# Out:
#  There are 740 results in this dataframe

# %%
#NOTE: Data csv produced in below row after clean step, in case there ARE any results where humidity > 100%
city_weather.head()
# Out:
#           City Country      Lat       Lng  Max Temp (Celsius)  Humidity %  \
# 0       Albany      US  42.6001  -73.9662                1.11          59
# 1  George Town      MY   5.4112  100.3354               30.00          79
# 2      Mataura      NZ -46.1927  168.8643               12.78          81
# 3         Biak      ID  -0.9131  122.8766               28.38          70
# 4         Poum      NC -20.2333  164.0167               25.32          81
#
#    Cloudiness %  Wind Speed (kmph)        Date
# 0            58               0.45  1619059798
# 1            20               1.54  1619059589
# 2            92               1.79  1619059800
# 3            73               2.42  1619059801
# 4            17               3.94  1619059803

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check to see if any rows have huminity > 100%
humidity_check = city_weather['Humidity %'].describe(include = 'all')
humidity_check
# Out:
# count    740.000000
# mean      68.650000
# std       22.696156
# min        8.000000
# 25%       57.000000
# 50%       74.000000
# 75%       87.000000
# max      100.000000
# Name: Humidity %, dtype: float64

# %%
humidity_count_df = city_weather[city_weather['Humidity %'] > 100]

print(f'There are {humidity_count_df["City"].count()} cities in this dataset with humidity greater than 100%')
# Out:
# There are 0 cities in this dataset with humidity greater than 100%

# %%
#  Get the indices of cities that have humidity over 100%.
indexNames = city_weather[city_weather["Humidity %"] > 100].index

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_weather = city_weather.drop(indexNames, inplace = False)
clean_city_weather['Date'] = pd.to_datetime(clean_city_weather['Date'], unit = 's')
date_data_collected = pd.to_datetime(clean_city_weather['Date'][0]).strftime('%d/%m/%Y')
clean_city_weather.head()
# Out:
#           City Country      Lat       Lng  Max Temp (Celsius)  Humidity %  \
# 0       Albany      US  42.6001  -73.9662                1.11          59
# 1  George Town      MY   5.4112  100.3354               30.00          79
# 2      Mataura      NZ -46.1927  168.8643               12.78          81
# 3         Biak      ID  -0.9131  122.8766               28.38          70
# 4         Poum      NC -20.2333  164.0167               25.32          81
#
#    Cloudiness %  Wind Speed (kmph)                Date
# 0            58               0.45 2021-04-22 02:49:58
# 1            20               1.54 2021-04-22 02:46:29
# 2            92               1.79 2021-04-22 02:50:00
# 3            73               2.42 2021-04-22 02:50:01
# 4            17               3.94 2021-04-22 02:50:03

# %%
print(f' There are {clean_city_weather["City"].count()} results in this cleaned dataframe\
\n i.e. {clean_city_weather["City"].count() - city_weather["City"].count()} results were removed.')
clean_city_weather.to_csv("../output_data/cities_FINAL.csv")
# Out:
#  There are 740 results in this cleaned dataframe
#  i.e. 0 results were removed.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
def latitude_temp():
    plt.figure(figsize=(10,5))
    x_axis = clean_city_weather['Lat']
    y_axis = clean_city_weather['Max Temp (Celsius)']
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Max Temperature (Celcius)')
    plt.title('City Latitude vs. Max Temperature (Celcius) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/City Latitude vs. Max Temperature (Celcius).png")
latitude_temp()
print(f'The diagram shows the relationship between the latitude and max temperatures (measured in degrees celsius) of individual cities in the sample dataset.\
\nIt would appear that the max temperatures seem to be the highest for cities closest to the equator.')
# Out:
# The diagram shows the relationship between the latitude and max temperatures (measured in degrees celsius) of individual cities in the sample dataset.
# It would appear that the max temperatures seem to be the highest for cities closest to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
def latitude_humidity():
    plt.figure(figsize=(10,5))
    x_axis = clean_city_weather['Lat']
    y_axis = clean_city_weather['Humidity %']
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Humidity %')
    plt.title('City Latitude vs. Humidity (%) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/City Latitude vs. Humidity (%).png")
latitude_humidity()
print(f'The plot does not appear to demonstrate any relationship between latitude and humidity levels.')
# Out:
# The plot does not appear to demonstrate any relationship between latitude and humidity levels.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
def latitude_cloudiness():
    plt.figure(figsize=(10,5))
    x_axis = clean_city_weather['Lat']
    y_axis = clean_city_weather['Cloudiness %']
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Cloudiness (%)')
    plt.title('City Latitude vs. Cloudiness (%) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/City Latitude vs. Cloudiness (%).png")
latitude_cloudiness()
print(f'The plot does not appear to demonstrate any relationship between latitude and cloudiness.')
# Out:
# The plot does not appear to demonstrate any relationship between latitude and cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
def latitude_wind_speed():
    plt.figure(figsize=(10,5))
    x_axis = clean_city_weather['Lat']
    y_axis = clean_city_weather['Wind Speed (kmph)']
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Wind Speed (kmph)')
    plt.title('City Latitude vs. Wind Speed (kmph) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/City Latitude vs. Wind Speed (kmph).png")
latitude_wind_speed()
print(f'The diagram perhaps demonstrates a loose relationship relationship between latitude and wind speeds.\
\nWind speeds appear to be minimal on the equator, with the most spread furthest away.')
# Out:
# The diagram perhaps demonstrates a loose relationship relationship between latitude and wind speeds.
# Wind speeds appear to be minimal on the equator, with the most spread furthest away.

# %% [markdown]
# ## Linear Regression

# %%
#create two dfs, one for Northern Hermisphere (Latitude >= 0) and Southern Hermisphere (Latitude < 0)
#We will treat any cities that are on exactly 0 latitude to belong to Northern.
import scipy.stats as st
from scipy.stats import linregress
n_hemi_data = clean_city_weather.loc[clean_city_weather["Lat"] >= 0]
n_hemi_data.head()
# Out:
#            City Country      Lat       Lng  Max Temp (Celsius)  Humidity %  \
# 0        Albany      US  42.6001  -73.9662                1.11          59
# 1   George Town      MY   5.4112  100.3354               30.00          79
# 5         Tiksi      RU  71.6872  128.8694              -10.99          79
# 8        Lander      US  42.8330 -108.7307                4.00          48
# 10     Tasiilaq      GL  65.6145  -37.6368               -3.00          54
#
#     Cloudiness %  Wind Speed (kmph)                Date
# 0             58               0.45 2021-04-22 02:49:58
# 1             20               1.54 2021-04-22 02:46:29
# 5             95               4.84 2021-04-22 02:50:04
# 8              1               2.43 2021-04-22 02:50:07
# 10            75               8.75 2021-04-22 02:50:10

# %%
s_hemi_data = clean_city_weather.loc[clean_city_weather["Lat"] < 0]
s_hemi_data.head()
# Out:
#       City Country      Lat       Lng  Max Temp (Celsius)  Humidity %  \
# 2  Mataura      NZ -46.1927  168.8643               12.78          81
# 3     Biak      ID  -0.9131  122.8766               28.38          70
# 4     Poum      NC -20.2333  164.0167               25.32          81
# 6  Kavieng      PG  -2.5744  150.7967               29.06          69
# 7   Hobart      AU -42.8794  147.3294               16.00          41
#
#    Cloudiness %  Wind Speed (kmph)                Date
# 2            92               1.79 2021-04-22 02:50:00
# 3            73               2.42 2021-04-22 02:50:01
# 4            17               3.94 2021-04-22 02:50:03
# 6            82               4.25 2021-04-22 02:50:05
# 7            40              10.29 2021-04-22 02:49:34

# %%
total_cities = clean_city_weather["City"].count()
n_city_count = n_hemi_data["City"].count()
s_city_count = s_hemi_data["City"].count()

print("There are {}({:.1%}) cities out of {} in this dataset localed in the Northern Hermisphere."
      .format(n_city_count, n_city_count/total_cities, total_cities))
      
print("There are {}({:.1%}) cities out of {} in this dataset localed in the Southern Hermisphere."
      .format(s_city_count, s_city_count/total_cities, total_cities))
# Out:
# There are 520(70.3%) cities out of 740 in this dataset localed in the Northern Hermisphere.
# There are 220(29.7%) cities out of 740 in this dataset localed in the Southern Hermisphere.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
def latitude_temp_regression_north():
    plt.figure(figsize=(10,5))
    x_axis = n_hemi_data['Lat']
    y_axis = n_hemi_data['Max Temp (Celsius)']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Max Temperature (Celcius)')
    plt.title('Northern Hermisphere City Latitude vs. Max Temperature (Celcius) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Northern Hermisphere City Latitude vs. Max Temperature (Celcius) Regression.png")
latitude_temp_regression_north()
print(f'The diagram shows the relationship between the latitude and max temperatures (measured in degrees celsius) of individual\
\ncities in the northern hemisphere of the sample dataset.\
\nThe correlation coefficient would suggest a relatively strong relationship between the two variables.\
\nIt would appear to also support the preceeding suggestion that temperatures tend to be higher closer to the equator.')
# Out:
# The correlation coefficient is: -0.88
#
# The diagram shows the relationship between the latitude and max temperatures (measured in degrees celsius) of individual
# cities in the northern hemisphere of the sample dataset.
# The correlation coefficient would suggest a relatively strong relationship between the two variables.
# It would appear to also support the preceeding suggestion that temperatures tend to be higher closer to the equator.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
def latitude_temp_regression_south():
    plt.figure(figsize=(10,5))
    x_axis = s_hemi_data['Lat']
    y_axis = s_hemi_data['Max Temp (Celsius)']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Max Temperature (Celcius)')
    plt.title('Southern Hermisphere City Latitude vs. Max Temperature (Celcius) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Southern Hermisphere City Latitude vs. Max Temperature (Celcius) Regression.png")
latitude_temp_regression_south()
print(f'The diagram shows the relationship between the latitude and max temperatures (measured in degrees celsius) of individual\
\ncities in the southern hemisphere of the sample dataset.\
\nThe correlation coefficient however, suggests a weaker relationship between the two variables when compared to the northern hermisphere.\
\nIt does however, still appear to also support the earlier suggestion that temperatures tend to be higher closer to the equator.')
# Out:
# The correlation coefficient is: 0.7
#
# The diagram shows the relationship between the latitude and max temperatures (measured in degrees celsius) of individual
# cities in the southern hemisphere of the sample dataset.
# The correlation coefficient however, suggests a weaker relationship between the two variables when compared to the northern hermisphere.
# It does however, still appear to also support the earlier suggestion that temperatures tend to be higher closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
def latitude_humidity_regression_north():
    plt.figure(figsize=(10,5))
    x_axis = n_hemi_data['Lat']
    y_axis = n_hemi_data['Humidity %']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Humidity %')
    plt.title('Northern Hermisphere City Latitude vs. Humidity % ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Northern Hermisphere City Latitude vs. Humidity % Regression.png")
latitude_humidity_regression_north()
print(f'The diagram shows the relationship between the latitude and humidity % of individual\
\ncities in the northern hemisphere of the sample dataset.\
\nThe correlation coefficient suggests a weak relationship between the two variables.\
\nIt would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.')
# Out:
# The correlation coefficient is: 0.06
#
# The diagram shows the relationship between the latitude and humidity % of individual
# cities in the northern hemisphere of the sample dataset.
# The correlation coefficient suggests a weak relationship between the two variables.
# It would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
def latitude_humidity_regression_south():
    plt.figure(figsize=(10,5))
    x_axis = s_hemi_data['Lat']
    y_axis = s_hemi_data['Humidity %']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Humidity %')
    plt.title('Southern Hermisphere City Latitude vs. Humidity % ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Southern Hermisphere City Latitude vs. Humidity % Regression.png")
latitude_humidity_regression_south()
print(f'The diagram shows the relationship between the latitude and humidity % of individual\
\ncities in the southern hemisphere of the sample dataset.\
\nThe correlation coefficient suggests a relatively weak relationship between the two variables.\
\nIt would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.\
\nHowever, there is perhaps marginally more of a relationship between latitude and humidity in the southern hermisphere over the north.\
\nThis observation could also be skewed slightly from the density of cities with higher humidity close to the equator')
# Out:
# The correlation coefficient is: 0.14
#
# The diagram shows the relationship between the latitude and humidity % of individual
# cities in the southern hemisphere of the sample dataset.
# The correlation coefficient suggests a relatively weak relationship between the two variables.
# It would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.
# However, there is perhaps marginally more of a relationship between latitude and humidity in the southern hermisphere over the north.
# This observation could also be skewed slightly from the density of cities with higher humidity close to the equator

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
def latitude_cloudiness_regression_north():
    plt.figure(figsize=(10,5))
    x_axis = n_hemi_data['Lat']
    y_axis = n_hemi_data['Cloudiness %']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Cloudiness %')
    plt.title('Northern Hermisphere City Latitude vs. Cloudiness % ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Northern Hermisphere City Latitude vs. Cloudiness % Regression.png")
latitude_cloudiness_regression_north()
print(f'The diagram shows the relationship between the latitude and cloudiness % of individual\
\ncities in the northern hemisphere of the sample dataset.\
\nThe correlation coefficient suggests a weak relationship between the two variables.\
\nIt would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.')
# Out:
# The correlation coefficient is: 0.08
#
# The diagram shows the relationship between the latitude and cloudiness % of individual
# cities in the northern hemisphere of the sample dataset.
# The correlation coefficient suggests a weak relationship between the two variables.
# It would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
def latitude_cloudiness_regression_south():
    plt.figure(figsize=(10,5))
    x_axis = s_hemi_data['Lat']
    y_axis = s_hemi_data['Cloudiness %']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Cloudiness %')
    plt.title('Southern Hermisphere City Latitude vs. Cloudiness % ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Southern Hermisphere City Latitude vs. Cloudiness % Regression.png")
latitude_cloudiness_regression_south()
print(f'The diagram shows the relationship between the latitude and cloudiness % of individual\
\ncities in the southern hemisphere of the sample dataset.\
\nThe correlation coefficient suggests a relatively weak relationship between the two variables.\
\nIt would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.\
\nHowever, there is perhaps marginally more of a relationship between latitude and cloudiness in the southern hermisphere over the north.\
\nThis observation could also be skewed slightly from the density of cities with 100% cloudiness close to the equator')
# Out:
# The correlation coefficient is: 0.12
#
# The diagram shows the relationship between the latitude and cloudiness % of individual
# cities in the southern hemisphere of the sample dataset.
# The correlation coefficient suggests a relatively weak relationship between the two variables.
# It would appear to also support the preceeding suggestion that there is a lack of relationship between the two variables.
# However, there is perhaps marginally more of a relationship between latitude and cloudiness in the southern hermisphere over the north.
# This observation could also be skewed slightly from the density of cities with 100% cloudiness close to the equator

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
def latitude_wind_regression_north():
    plt.figure(figsize=(10,5))
    x_axis = n_hemi_data['Lat']
    y_axis = n_hemi_data['Wind Speed (kmph)']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Wind Speed (kmph)')
    plt.title('Northern Hermisphere City Latitude vs. Wind Speed (kmph) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Northern Hermisphere City Latitude vs. Wind Speed (kmph) Regression.png")
latitude_wind_regression_north()
print(f'The diagram shows the relationship between the latitude and wind speed (kmph) of individual\
\ncities in the northern hemisphere of the sample dataset.\
\nThe correlation coefficient suggests a relatively weak relationship between the two variables.')
# Out:
# The correlation coefficient is: 0.2
#
# The diagram shows the relationship between the latitude and wind speed (kmph) of individual
# cities in the northern hemisphere of the sample dataset.
# The correlation coefficient suggests a relatively weak relationship between the two variables.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
def latitude_wind_regression_south():
    plt.figure(figsize=(10,5))
    x_axis = s_hemi_data['Lat']
    y_axis = s_hemi_data['Wind Speed (kmph)']
    correlation = st.pearsonr(x_axis, y_axis)
    print(f'The correlation coefficient is: {round(correlation[0],2)}\
     \n')
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_axis, y_axis, edgecolors = 'grey', s = 20, zorder = 3)
    plt.plot(x_axis,regress_values,"r-")
    plt.annotate( line_eq, xy = (0.1,0.18), xycoords = 'figure fraction', horizontalalignment = 'left', verticalalignment='bottom', fontsize=15, color="red")
    plt.grid(zorder = 0, color = 'lightgrey')
    plt.xlabel('Latitude')
    plt.ylabel('Wind Speed (kmph)')
    plt.title('Southern Hermisphere City Latitude vs. Wind Speed (kmph) ({})'.format(date_data_collected), fontweight = 'bold')
    plt.savefig("../output_data/Southern Hermisphere City Latitude vs. Wind Speed (kmph) Regression.png")
latitude_wind_regression_south()
print(f'The diagram shows the relationship between the latitude and wind speed (kmph) of individual\
\ncities in the southern hemisphere of the sample dataset.\
\nThe correlation coefficient suggests a relatively weak relationship between the two variables.\
\nHowever, there is perhaps marginally more of a relationship between latitude and wind speed in the southern hermisphere over the north.\
\nThis observation however, could be skewed slightly from the density of cities close to the equator.')
# Out:
# The correlation coefficient is: -0.28
#
# The diagram shows the relationship between the latitude and wind speed (kmph) of individual
# cities in the southern hemisphere of the sample dataset.
# The correlation coefficient suggests a relatively weak relationship between the two variables.
# However, there is perhaps marginally more of a relationship between latitude and wind speed in the southern hermisphere over the north.
# This observation however, could be skewed slightly from the density of cities close to the equator.
